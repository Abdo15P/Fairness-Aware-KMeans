# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdo15P/Fairness-Aware-KMeans/blob/main/near-foreign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# from preprocessing import preprocessing
# from KmeansppClass import K_Means
# from balance_measure import balance_measure
# from cluster_quality_measure import cluster_quality_measure
# from fairness_measure import fairness_measure
# from clustering_for_income import clustering_for_income

def near_foreign_reassignment_combined(data, predictions, sensitive_features, centroids, k, max_swaps=1000):
    print("Starting Near-Foreign Reassignment to improve fairness...")
    print(" ")

    ###########################################################################
    ################### 1- Make new combined Feature (race + gender) ##########
    ###########################################################################

    if len(sensitive_features.shape) == 1:
        sensitive_features = np.reshape(sensitive_features, (sensitive_features.shape[0], 1)) #reshape to column vector
    fair_preds = predictions.copy()

    combination = []
    n_sensitive_features = sensitive_features.shape[1]

    #merge sensitive attributes into one categorical combination
    for i in range(data.shape[0]):
        new_feature = ""
        for j in range(n_sensitive_features):
            new_feature = new_feature + sensitive_features[i, j]
            if j != n_sensitive_features - 1:
                new_feature = new_feature + " "
        combination.append(new_feature)


    #############################################################################
    ################### 2- get statistics for balance measure ###################
    #############################################################################

    combination = np.array(combination)
    combinations = list(set(combination))

    n_combinations = len(combinations)
    combinations_count = []

    cluster_combinations_counts = np.zeros((k, n_combinations))
    for i in range(k):
        combination_in_cluster = (combination[fair_preds == i])
        for j in range(n_combinations):
            cluster_combinations_counts[i, j] = np.sum(combination_in_cluster == combinations[j]) #count of data points belonging to combination j inside cluster i.

    #percentages of each combination within each cluster.
    cluster_combinations_perc = np.zeros_like(cluster_combinations_counts)
    for i in range(k):
        cluster_combinations_perc[i] = cluster_combinations_counts[i] / np.sum(cluster_combinations_counts[i])
    cluster_combinations_perc = cluster_combinations_perc * 100

    #golbal count of each combination
    for i in range(n_combinations):
      total_count = 0
      for j in range(k):
        total_count = total_count + cluster_combinations_counts[j, i]
      combinations_count.append(total_count)

    #golbal percentage of each combination
    combinations_count = np.array(combinations_count)
    combinations_perc = (combinations_count / np.sum(combinations_count)) * 100

    print("Initial statistics")
    print("cluster combined count", cluster_combinations_counts)
    print("cluster combined percent", cluster_combinations_perc)
    print(" ")
    print("combined count", combinations_count)
    print("combined percent", combinations_perc)
    print(" ")
    bcss, wcss = cluster_quality_measure(data, centroids, cluster_combinations_counts, fair_preds)
    initial_cluster_quality = bcss / (bcss + wcss)
    initial_fairness_quality = fairness_measure(cluster_combinations_counts, cluster_combinations_perc,
                                                combinations_perc, k)

    ##############################################################################
    ################### 3- calculate nearest foreign heuristic ###################
    ##############################################################################

    distances = []
    idx = []
    destination_idx = []
    for i, point in enumerate(data):
        flag = 1
        min_distance = 0
        min_idx = int(fair_preds[i])
        for j in range(k):
            if int(fair_preds[i]) != j:
                distance = np.linalg.norm(point - centroids[j])
                if flag == 1:
                    min_distance = distance
                    min_idx = j
                    flag = 0
                elif distance < min_distance:
                    min_distance = distance
                    min_idx = j

        idx.append(i)
        destination_idx.append(min_idx)
        distances.append(min_distance)

    sorted_d_to_foreign = sorted(zip(idx, destination_idx, distances), key=lambda x:x[2])

    #################################################################
    ################### 4- reassignment algorithm ###################
    #################################################################

    reassignment_count = 0
    no_change = 1
    last_cluster_quality = 0
    last_fairness_quality = 0


    #reassign until all combination deviations are below 10%.
    for i, (idx, destination_idx, _) in enumerate(sorted_d_to_foreign):
        ################### \1/ measure cluster balance error from global balance ###################
        deviations = balance_measure(cluster_combinations_perc, combinations_perc)
        if all(dev < 10 for dev in deviations):
            print("Clusters balanced")
            last_centroids = {}
            last_classes = {}
            for i in range(k):
                last_classes[i] = []
            for j, point in enumerate(data):
                for c in range(k):
                    if fair_preds[j] == c:
                        last_classes[c].append(point)
            for i in range(k):
                last_centroids[i] = np.average(last_classes[i], axis=0)

            bcss, wcss = cluster_quality_measure(data, last_centroids, cluster_combinations_counts, fair_preds)
            last_cluster_quality = bcss / (bcss + wcss)
            print("cluster_quality is ", last_cluster_quality)
            last_fairness_quality = fairness_measure(cluster_combinations_counts, cluster_combinations_perc, combinations_perc, k)
            print("fairness_quality is ", last_fairness_quality)
            print("Objective function========================================== ", last_cluster_quality + 1-last_fairness_quality)
            return fair_preds, initial_cluster_quality, last_cluster_quality, initial_fairness_quality, last_fairness_quality, no_change, 0

        no_change = 0


        print("No. of Reassignments ", reassignment_count)



        ################### \2/ reassignm cluster membership ###################
        source_cluster = int(fair_preds[idx])
        member_combination = combination[idx]  # check
        comb_idx = combinations.index(member_combination)
        if ((cluster_combinations_perc[source_cluster, comb_idx] - combinations_perc[comb_idx] < 10) or
         ((cluster_combinations_perc[source_cluster, comb_idx]) < (cluster_combinations_perc[destination_idx, comb_idx]))):

            print("Skip point")
            continue

        fair_preds[idx] = destination_idx
        reassignment_count = reassignment_count + 1
        print(reassignment_count)

        # update cluster counts and percentage
        cluster_combinations_counts[source_cluster, comb_idx] = cluster_combinations_counts[source_cluster, comb_idx] - 1
        cluster_combinations_counts[destination_idx, comb_idx] = cluster_combinations_counts[destination_idx, comb_idx] + 1

        cluster_combinations_perc = np.zeros_like(cluster_combinations_counts)
        for i in range(k):
            cluster_combinations_perc[i] = cluster_combinations_counts[i] / np.sum(cluster_combinations_counts[i])
        cluster_combinations_perc = cluster_combinations_perc * 100

        print("cluster combined count")
        for i in range(k):
            print(cluster_combinations_counts[i])
            print("cluster combined percent")
        for i in range(k):
            print(cluster_combinations_perc[i])
        print("combined count", combinations_count)
        print("combined percent", combinations_perc)
        print(" ")
        if reassignment_count >= max_swaps:
            print(f"Reached max swaps limit ({max_swaps}). Stopping.")

            # 1. Recalculate the NEW physical centroids after swapping
            last_centroids = {}
            for c in range(k):
                cluster_points = data[fair_preds == c]
                if len(cluster_points) > 0:
                    last_centroids[c] = np.average(cluster_points, axis=0)
                else:
                    last_centroids[c] = centroids[c] # Fallback if empty

            # 2. Measure quality using the NEW centroids
            final_cluster_sizes = [np.sum(fair_preds == c) for c in range(k)]
            bcss, wcss = cluster_quality_measure(data, last_centroids, final_cluster_sizes, fair_preds)

            last_cluster_quality = bcss / (bcss + wcss) if (bcss+wcss) > 0 else 0
            last_fairness_quality = fairness_measure(cluster_combinations_counts, cluster_combinations_perc, combinations_perc, k)

            return fair_preds, initial_cluster_quality, last_cluster_quality, initial_fairness_quality, last_fairness_quality, 0, 0

    print(combinations)
    return fair_preds, initial_cluster_quality, last_cluster_quality, initial_fairness_quality, last_fairness_quality, no_change, 1


def main():
    data, sensitive_features, income = preprocessing()
    K = 2
    k_means = K_Means(K)
    k_means.fit(data)
    labels = np.zeros((data.shape[0],))
    for i in range(data.shape[0]):
        labels[i] = k_means.predict(data[i])

    result = pd.DataFrame({
        "cluster": labels,
        "income": income
    })

    print(pd.crosstab(result["cluster"], result["income"], normalize='index'))
    print(pd.crosstab(labels, sensitive_features[:, 0], normalize='index'))
    print(pd.crosstab(labels, sensitive_features[:, 1], normalize='index'))

    print("Initial clustering to predict income: ")
    _ = clustering_for_income(labels, income, K)

    fair_predictions, initial_cluster_quality, last_cluster_quality, initial_fairness_quality, last_fairness_quality, no_change, failed = (
        near_foreign_reassignment_combined(data, labels, sensitive_features[:, 1], k_means.centroids, K))

    for i in range(K):
        print("Initial Cluster ", i, "size ", np.sum(labels == i))
        print("Last Cluster ", i, "size ", np.sum(fair_predictions == i))
    print("Initial Clustering Quality ", initial_cluster_quality)
    print("Last Clustering Quality ", last_cluster_quality)
    print("Initial Fairness Quality ", initial_fairness_quality)
    print("Last Fairness Quality ", last_fairness_quality)
    print("No change? ", no_change)
    print("Failed? ", failed)
    print(" ")
    print("Last clustering to predict income: ")
    _ = clustering_for_income(fair_predictions, income, K)
    print("Clustering quality change = ", ((last_cluster_quality - initial_cluster_quality) / initial_cluster_quality) * 100)

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# balance measure
# No. of Reassignments  743
# Skip point
#
# balance measure
# No. of Reassignments  743
# Skip point
#
# balance measure
# No. of Reassignments  743
# Skip point
#
# balance measure
# No. of Reassignments  743
# Skip point
#
# balance measure
# No. of Reassignments  743
# 744
# cluster combined count
# [ 4045. 12867.]
# cluster combined percent
# [5737. 7513.]
# cluster combined percent
# [23.9179281 76.0820719]
# [43.29811321 56.70188679]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  744
# Skip point
#
# balance measure
# No. of Reassignments  744
# Skip point
#
# balance measure
# No. of Reassignments  744
# Skip point
#
# balance measure
# No. of Reassignments  744
# 745
# cluster combined count
# [ 4046. 12867.]
# cluster combined percent
# [5736. 7513.]
# cluster combined percent
# [23.92242654 76.07757346]
# [43.2938335 56.7061665]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  745
# Skip point
#
# balance measure
# No. of Reassignments  745
# Skip point
#
# balance measure
# No. of Reassignments  745
# Skip point
#
# balance measure
# No. of Reassignments  745
# Skip point
#
# balance measure
# No. of Reassignments  745
# Skip point
#
# balance measure
# No. of Reassignments  745
# Skip point
#
# balance measure
# No. of Reassignments  745
# Skip point
#
# balance measure
# No. of Reassignments  745
# Skip point
#
# balance measure
# No. of Reassignments  745
# 746
# cluster combined count
# [ 4047. 12867.]
# cluster combined percent
# [5735. 7513.]
# cluster combined percent
# [23.92692444 76.07307556]
# [43.28955314 56.71044686]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  746
# Skip point
#
# balance measure
# No. of Reassignments  746
# 747
# cluster combined count
# [ 4048. 12867.]
# cluster combined percent
# [5734. 7513.]
# cluster combined percent
# [23.93142181 76.06857819]
# [43.28527214 56.71472786]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  747
# 748
# cluster combined count
# [ 4049. 12867.]
# cluster combined percent
# [5733. 7513.]
# cluster combined percent
# [23.93591866 76.06408134]
# [43.28099049 56.71900951]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  748
# Skip point
#
# balance measure
# No. of Reassignments  748
# Skip point
#
# balance measure
# No. of Reassignments  748
# Skip point
#
# balance measure
# No. of Reassignments  748
# Skip point
#
# balance measure
# No. of Reassignments  748
# Skip point
#
# balance measure
# No. of Reassignments  748
# Skip point
#
# balance measure
# No. of Reassignments  748
# Skip point
#
# balance measure
# No. of Reassignments  748
# 749
# cluster combined count
# [ 4050. 12867.]
# cluster combined percent
# [5732. 7513.]
# cluster combined percent
# [23.94041497 76.05958503]
# [43.27670819 56.72329181]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  749
# Skip point
#
# balance measure
# No. of Reassignments  749
# 750
# cluster combined count
# [ 4051. 12867.]
# cluster combined percent
# [5731. 7513.]
# cluster combined percent
# [23.94491075 76.05508925]
# [43.27242525 56.72757475]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  750
# 751
# cluster combined count
# [ 4052. 12867.]
# cluster combined percent
# [5730. 7513.]
# cluster combined percent
# [23.94940599 76.05059401]
# [43.26814166 56.73185834]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  751
# Skip point
#
# balance measure
# No. of Reassignments  751
# Skip point
#
# balance measure
# No. of Reassignments  751
# Skip point
#
# balance measure
# No. of Reassignments  751
# Skip point
#
# balance measure
# No. of Reassignments  751
# Skip point
#
# balance measure
# No. of Reassignments  751
# Skip point
#
# balance measure
# No. of Reassignments  751
# Skip point
#
# balance measure
# No. of Reassignments  751
# 752
# cluster combined count
# [ 4053. 12867.]
# cluster combined percent
# [5729. 7513.]
# cluster combined percent
# [23.95390071 76.04609929]
# [43.26385742 56.73614258]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  752
# 753
# cluster combined count
# [ 4054. 12867.]
# cluster combined percent
# [5728. 7513.]
# cluster combined percent
# [23.95839489 76.04160511]
# [43.25957254 56.74042746]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  753
# Skip point
#
# balance measure
# No. of Reassignments  753
# Skip point
#
# balance measure
# No. of Reassignments  753
# Skip point
#
# balance measure
# No. of Reassignments  753
# Skip point
#
# balance measure
# No. of Reassignments  753
# Skip point
#
# balance measure
# No. of Reassignments  753
# 754
# cluster combined count
# [ 4055. 12867.]
# cluster combined percent
# [5727. 7513.]
# cluster combined percent
# [23.96288855 76.03711145]
# [43.25528701 56.74471299]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  754
# Skip point
#
# balance measure
# No. of Reassignments  754
# Skip point
#
# balance measure
# No. of Reassignments  754
# Skip point
#
# balance measure
# No. of Reassignments  754
# Skip point
#
# balance measure
# No. of Reassignments  754
# 755
# cluster combined count
# [ 4056. 12867.]
# cluster combined percent
# [5726. 7513.]
# cluster combined percent
# [23.96738167 76.03261833]
# [43.25100083 56.74899917]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  755
# 756
# cluster combined count
# [ 4057. 12867.]
# cluster combined percent
# [5725. 7513.]
# cluster combined percent
# [23.97187426 76.02812574]
# [43.24671401 56.75328599]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  756
# Skip point
#
# balance measure
# No. of Reassignments  756
# Skip point
#
# balance measure
# No. of Reassignments  756
# Skip point
#
# balance measure
# No. of Reassignments  756
# 757
# cluster combined count
# [ 4058. 12867.]
# cluster combined percent
# [5724. 7513.]
# cluster combined percent
# [23.97636632 76.02363368]
# [43.24242653 56.75757347]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  757
# 758
# cluster combined count
# [ 4059. 12867.]
# cluster combined percent
# [5723. 7513.]
# cluster combined percent
# [23.98085785 76.01914215]
# [43.23813841 56.76186159]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# Skip point
#
# balance measure
# No. of Reassignments  758
# 759
# cluster combined count
# [ 4060. 12867.]
# cluster combined percent
# [5722. 7513.]
# cluster combined percent
# [23.98534885 76.01465115]
# [43.23384964 56.76615036]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  759
# 760
# cluster combined count
# [ 4061. 12867.]
# cluster combined percent
# [5721. 7513.]
# cluster combined percent
# [23.98983932 76.01016068]
# [43.22956022 56.77043978]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  760
# 761
# cluster combined count
# [ 4062. 12867.]
# cluster combined percent
# [5720. 7513.]
# cluster combined percent
# [23.99432926 76.00567074]
# [43.22527016 56.77472984]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  761
# Skip point
#
# balance measure
# No. of Reassignments  761
# Skip point
#
# balance measure
# No. of Reassignments  761
# 762
# cluster combined count
# [ 4063. 12867.]
# cluster combined percent
# [5719. 7513.]
# cluster combined percent
# [23.99881867 76.00118133]
# [43.22097944 56.77902056]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  762
# Skip point
#
# balance measure
# No. of Reassignments  762
# Skip point
#
# balance measure
# No. of Reassignments  762
# Skip point
#
# balance measure
# No. of Reassignments  762
# Skip point
#
# balance measure
# No. of Reassignments  762
# Skip point
#
# balance measure
# No. of Reassignments  762
# Skip point
#
# balance measure
# No. of Reassignments  762
# Skip point
#
# balance measure
# No. of Reassignments  762
# 763
# cluster combined count
# [ 4064. 12867.]
# cluster combined percent
# [5718. 7513.]
# cluster combined percent
# [24.00330754 75.99669246]
# [43.21668808 56.78331192]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  763
# Skip point
#
# balance measure
# No. of Reassignments  763
# Skip point
#
# balance measure
# No. of Reassignments  763
# Skip point
#
# balance measure
# No. of Reassignments  763
# 764
# cluster combined count
# [ 4065. 12867.]
# cluster combined percent
# [5717. 7513.]
# cluster combined percent
# [24.00779589 75.99220411]
# [43.21239607 56.78760393]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  764
# 765
# cluster combined count
# [ 4066. 12867.]
# cluster combined percent
# [5716. 7513.]
# cluster combined percent
# [24.01228371 75.98771629]
# [43.20810341 56.79189659]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  765
# Skip point
#
# balance measure
# No. of Reassignments  765
# 766
# cluster combined count
# [ 4067. 12867.]
# cluster combined percent
# [5715. 7513.]
# cluster combined percent
# [24.01677099 75.98322901]
# [43.2038101 56.7961899]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  766
# 767
# cluster combined count
# [ 4068. 12867.]
# cluster combined percent
# [5714. 7513.]
# cluster combined percent
# [24.02125775 75.97874225]
# [43.19951614 56.80048386]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  767
# Skip point
#
# balance measure
# No. of Reassignments  767
# Skip point
#
# balance measure
# No. of Reassignments  767
# Skip point
#
# balance measure
# No. of Reassignments  767
# 768
# cluster combined count
# [ 4069. 12867.]
# cluster combined percent
# [5713. 7513.]
# cluster combined percent
# [24.02574398 75.97425602]
# [43.19522153 56.80477847]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  768
# Skip point
#
# balance measure
# No. of Reassignments  768
# Skip point
#
# balance measure
# No. of Reassignments  768
# Skip point
#
# balance measure
# No. of Reassignments  768
# Skip point
#
# balance measure
# No. of Reassignments  768
# Skip point
#
# balance measure
# No. of Reassignments  768
# Skip point
#
# balance measure
# No. of Reassignments  768
# 769
# cluster combined count
# [ 4070. 12867.]
# cluster combined percent
# [5712. 7513.]
# cluster combined percent
# [24.03022967 75.96977033]
# [43.19092628 56.80907372]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  769
# Skip point
#
# balance measure
# No. of Reassignments  769
# Skip point
#
# balance measure
# No. of Reassignments  769
# Skip point
#
# balance measure
# No. of Reassignments  769
# Skip point
#
# balance measure
# No. of Reassignments  769
# Skip point
#
# balance measure
# No. of Reassignments  769
# 770
# cluster combined count
# [ 4071. 12867.]
# cluster combined percent
# [5711. 7513.]
# cluster combined percent
# [24.03471484 75.96528516]
# [43.18663037 56.81336963]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  770
# Skip point
#
# balance measure
# No. of Reassignments  770
# 771
# cluster combined count
# [ 4072. 12867.]
# cluster combined percent
# [5710. 7513.]
# cluster combined percent
# [24.03919948 75.96080052]
# [43.18233381 56.81766619]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  771
# 772
# cluster combined count
# [ 4073. 12867.]
# cluster combined percent
# [5709. 7513.]
# cluster combined percent
# [24.04368359 75.95631641]
# [43.17803661 56.82196339]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  772
# Skip point
#
# balance measure
# No. of Reassignments  772
# Skip point
#
# balance measure
# No. of Reassignments  772
# Skip point
#
# balance measure
# No. of Reassignments  772
# Skip point
#
# balance measure
# No. of Reassignments  772
# Skip point
#
# balance measure
# No. of Reassignments  772
# Skip point
#
# balance measure
# No. of Reassignments  772
# 773
# cluster combined count
# [ 4074. 12867.]
# cluster combined percent
# [5708. 7513.]
# cluster combined percent
# [24.04816717 75.95183283]
# [43.17373875 56.82626125]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  773
# Skip point
#
# balance measure
# No. of Reassignments  773
# Skip point
#
# balance measure
# No. of Reassignments  773
# Skip point
#
# balance measure
# No. of Reassignments  773
# Skip point
#
# balance measure
# No. of Reassignments  773
# Skip point
#
# balance measure
# No. of Reassignments  773
# Skip point
#
# balance measure
# No. of Reassignments  773
# 774
# cluster combined count
# [ 4075. 12867.]
# cluster combined percent
# [5707. 7513.]
# cluster combined percent
# [24.05265022 75.94734978]
# [43.16944024 56.83055976]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  774
# 775
# cluster combined count
# [ 4076. 12867.]
# cluster combined percent
# [5706. 7513.]
# cluster combined percent
# [24.05713274 75.94286726]
# [43.16514108 56.83485892]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  775
# Skip point
#
# balance measure
# No. of Reassignments  775
# Skip point
#
# balance measure
# No. of Reassignments  775
# Skip point
#
# balance measure
# No. of Reassignments  775
# 776
# cluster combined count
# [ 4077. 12867.]
# cluster combined percent
# [5705. 7513.]
# cluster combined percent
# [24.06161473 75.93838527]
# [43.16084128 56.83915872]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  776
# Skip point
#
# balance measure
# No. of Reassignments  776
# Skip point
#
# balance measure
# No. of Reassignments  776
# 777
# cluster combined count
# [ 4078. 12867.]
# cluster combined percent
# [5704. 7513.]
# cluster combined percent
# [24.06609619 75.93390381]
# [43.15654082 56.84345918]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  777
# Skip point
#
# balance measure
# No. of Reassignments  777
# 778
# cluster combined count
# [ 4079. 12867.]
# cluster combined percent
# [5703. 7513.]
# cluster combined percent
# [24.07057713 75.92942287]
# [43.15223971 56.84776029]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  778
# Skip point
#
# balance measure
# No. of Reassignments  778
# Skip point
#
# balance measure
# No. of Reassignments  778
# Skip point
#
# balance measure
# No. of Reassignments  778
# Skip point
#
# balance measure
# No. of Reassignments  778
# Skip point
#
# balance measure
# No. of Reassignments  778
# 779
# cluster combined count
# [ 4080. 12867.]
# cluster combined percent
# [5702. 7513.]
# cluster combined percent
# [24.07505753 75.92494247]
# [43.14793795 56.85206205]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  779
# Skip point
#
# balance measure
# No. of Reassignments  779
# Skip point
#
# balance measure
# No. of Reassignments  779
# Skip point
#
# balance measure
# No. of Reassignments  779
# 780
# cluster combined count
# [ 4081. 12867.]
# cluster combined percent
# [5701. 7513.]
# cluster combined percent
# [24.07953741 75.92046259]
# [43.14363554 56.85636446]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  780
# 781
# cluster combined count
# [ 4082. 12867.]
# cluster combined percent
# [5700. 7513.]
# cluster combined percent
# [24.08401676 75.91598324]
# [43.13933248 56.86066752]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  781
# Skip point
#
# balance measure
# No. of Reassignments  781
# Skip point
#
# balance measure
# No. of Reassignments  781
# Skip point
#
# balance measure
# No. of Reassignments  781
# 782
# cluster combined count
# [ 4083. 12867.]
# cluster combined percent
# [5699. 7513.]
# cluster combined percent
# [24.08849558 75.91150442]
# [43.13502876 56.86497124]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  782
# Skip point
#
# balance measure
# No. of Reassignments  782
# Skip point
#
# balance measure
# No. of Reassignments  782
# Skip point
#
# balance measure
# No. of Reassignments  782
# Skip point
#
# balance measure
# No. of Reassignments  782
# 783
# cluster combined count
# [ 4084. 12867.]
# cluster combined percent
# [5698. 7513.]
# cluster combined percent
# [24.09297387 75.90702613]
# [43.1307244 56.8692756]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  783
# 784
# cluster combined count
# [ 4085. 12867.]
# cluster combined percent
# [5697. 7513.]
# cluster combined percent
# [24.09745163 75.90254837]
# [43.12641938 56.87358062]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  784
# 785
# cluster combined count
# [ 4086. 12867.]
# cluster combined percent
# [5696. 7513.]
# cluster combined percent
# [24.10192886 75.89807114]
# [43.12211371 56.87788629]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  785
# 786
# cluster combined count
# [ 4087. 12867.]
# cluster combined percent
# [5695. 7513.]
# cluster combined percent
# [24.10640557 75.89359443]
# [43.11780739 56.88219261]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  786
# 787
# cluster combined count
# [ 4088. 12867.]
# cluster combined percent
# [5694. 7513.]
# cluster combined percent
# [24.11088175 75.88911825]
# [43.11350042 56.88649958]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  787
# Skip point
#
# balance measure
# No. of Reassignments  787
# Skip point
#
# balance measure
# No. of Reassignments  787
# Skip point
#
# balance measure
# No. of Reassignments  787
# Skip point
#
# balance measure
# No. of Reassignments  787
# Skip point
#
# balance measure
# No. of Reassignments  787
# Skip point
#
# balance measure
# No. of Reassignments  787
# 788
# cluster combined count
# [ 4089. 12867.]
# cluster combined percent
# [5693. 7513.]
# cluster combined percent
# [24.1153574 75.8846426]
# [43.10919279 56.89080721]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  788
# 789
# cluster combined count
# [ 4090. 12867.]
# cluster combined percent
# [5692. 7513.]
# cluster combined percent
# [24.11983252 75.88016748]
# [43.10488451 56.89511549]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  789
# Skip point
#
# balance measure
# No. of Reassignments  789
# Skip point
#
# balance measure
# No. of Reassignments  789
# Skip point
#
# balance measure
# No. of Reassignments  789
# Skip point
#
# balance measure
# No. of Reassignments  789
# Skip point
#
# balance measure
# No. of Reassignments  789
# Skip point
#
# balance measure
# No. of Reassignments  789
# Skip point
#
# balance measure
# No. of Reassignments  789
# Skip point
#
# balance measure
# No. of Reassignments  789
# 790
# cluster combined count
# [ 4091. 12867.]
# cluster combined percent
# [5691. 7513.]
# cluster combined percent
# [24.12430711 75.87569289]
# [43.10057558 56.89942442]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  790
# Skip point
#
# balance measure
# No. of Reassignments  790
# Skip point
#
# balance measure
# No. of Reassignments  790
# 791
# cluster combined count
# [ 4092. 12867.]
# cluster combined percent
# [5690. 7513.]
# cluster combined percent
# [24.12878118 75.87121882]
# [43.096266 56.903734]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  791
# Skip point
#
# balance measure
# No. of Reassignments  791
# Skip point
#
# balance measure
# No. of Reassignments  791
# 792
# cluster combined count
# [ 4093. 12867.]
# cluster combined percent
# [5689. 7513.]
# cluster combined percent
# [24.13325472 75.86674528]
# [43.09195576 56.90804424]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  792
# Skip point
#
# balance measure
# No. of Reassignments  792
# Skip point
#
# balance measure
# No. of Reassignments  792
# Skip point
#
# balance measure
# No. of Reassignments  792
# Skip point
#
# balance measure
# No. of Reassignments  792
# 793
# cluster combined count
# [ 4094. 12867.]
# cluster combined percent
# [5688. 7513.]
# cluster combined percent
# [24.13772773 75.86227227]
# [43.08764488 56.91235512]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  793
# Skip point
#
# balance measure
# No. of Reassignments  793
# Skip point
#
# balance measure
# No. of Reassignments  793
# 794
# cluster combined count
# [ 4095. 12867.]
# cluster combined percent
# [5687. 7513.]
# cluster combined percent
# [24.14220021 75.85779979]
# [43.08333333 56.91666667]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  794
# Skip point
#
# balance measure
# No. of Reassignments  794
# Skip point
#
# balance measure
# No. of Reassignments  794
# 795
# cluster combined count
# [ 4096. 12867.]
# cluster combined percent
# [5686. 7513.]
# cluster combined percent
# [24.14667217 75.85332783]
# [43.07902114 56.92097886]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  795
# Skip point
#
# balance measure
# No. of Reassignments  795
# Skip point
#
# balance measure
# No. of Reassignments  795
# Skip point
#
# balance measure
# No. of Reassignments  795
# Skip point
#
# balance measure
# No. of Reassignments  795
# Skip point
#
# balance measure
# No. of Reassignments  795
# Skip point
#
# balance measure
# No. of Reassignments  795
# Skip point
#
# balance measure
# No. of Reassignments  795
# Skip point
#
# balance measure
# No. of Reassignments  795
# Skip point
#
# balance measure
# No. of Reassignments  795
# 796
# cluster combined count
# [ 4097. 12867.]
# cluster combined percent
# [5685. 7513.]
# cluster combined percent
# [24.1511436 75.8488564]
# [43.07470829 56.92529171]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  796
# Skip point
#
# balance measure
# No. of Reassignments  796
# Skip point
#
# balance measure
# No. of Reassignments  796
# 797
# cluster combined count
# [ 4098. 12867.]
# cluster combined percent
# [5684. 7513.]
# cluster combined percent
# [24.1556145 75.8443855]
# [43.07039479 56.92960521]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  797
# Skip point
#
# balance measure
# No. of Reassignments  797
# Skip point
#
# balance measure
# No. of Reassignments  797
# 798
# cluster combined count
# [ 4099. 12867.]
# cluster combined percent
# [5683. 7513.]
# cluster combined percent
# [24.16008488 75.83991512]
# [43.06608063 56.93391937]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  798
# Skip point
#
# balance measure
# No. of Reassignments  798
# Skip point
#
# balance measure
# No. of Reassignments  798
# Skip point
#
# balance measure
# No. of Reassignments  798
# 799
# cluster combined count
# [ 4100. 12867.]
# cluster combined percent
# [5682. 7513.]
# cluster combined percent
# [24.16455472 75.83544528]
# [43.06176582 56.93823418]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  799
# Skip point
#
# balance measure
# No. of Reassignments  799
# 800
# cluster combined count
# [ 4101. 12867.]
# cluster combined percent
# [5681. 7513.]
# cluster combined percent
# [24.16902405 75.83097595]
# [43.05745036 56.94254964]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  800
# 801
# cluster combined count
# [ 4102. 12867.]
# cluster combined percent
# [5680. 7513.]
# cluster combined percent
# [24.17349284 75.82650716]
# [43.05313424 56.94686576]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  801
# 802
# cluster combined count
# [ 4103. 12867.]
# cluster combined percent
# [5679. 7513.]
# cluster combined percent
# [24.17796111 75.82203889]
# [43.04881747 56.95118253]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  802
# Skip point
#
# balance measure
# No. of Reassignments  802
# Skip point
#
# balance measure
# No. of Reassignments  802
# Skip point
#
# balance measure
# No. of Reassignments  802
# 803
# cluster combined count
# [ 4104. 12867.]
# cluster combined percent
# [5678. 7513.]
# cluster combined percent
# [24.18242885 75.81757115]
# [43.04450004 56.95549996]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  803
# 804
# cluster combined count
# [ 4105. 12867.]
# cluster combined percent
# [5677. 7513.]
# cluster combined percent
# [24.18689606 75.81310394]
# [43.04018196 56.95981804]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  804
# 805
# cluster combined count
# [ 4106. 12867.]
# cluster combined percent
# [5676. 7513.]
# cluster combined percent
# [24.19136275 75.80863725]
# [43.03586322 56.96413678]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  805
# Skip point
#
# balance measure
# No. of Reassignments  805
# 806
# cluster combined count
# [ 4107. 12867.]
# cluster combined percent
# [5675. 7513.]
# cluster combined percent
# [24.19582891 75.80417109]
# [43.03154383 56.96845617]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  806
# 807
# cluster combined count
# [ 4108. 12867.]
# cluster combined percent
# [5674. 7513.]
# cluster combined percent
# [24.20029455 75.79970545]
# [43.02722378 56.97277622]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# Skip point
#
# balance measure
# No. of Reassignments  807
# 808
# cluster combined count
# [ 4109. 12867.]
# cluster combined percent
# [5673. 7513.]
# cluster combined percent
# [24.20475966 75.79524034]
# [43.02290308 56.97709692]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  808
# Skip point
#
# balance measure
# No. of Reassignments  808
# Skip point
#
# balance measure
# No. of Reassignments  808
# Skip point
#
# balance measure
# No. of Reassignments  808
# Skip point
#
# balance measure
# No. of Reassignments  808
# 809
# cluster combined count
# [ 4110. 12867.]
# cluster combined percent
# [5672. 7513.]
# cluster combined percent
# [24.20922424 75.79077576]
# [43.01858172 56.98141828]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  809
# Skip point
#
# balance measure
# No. of Reassignments  809
# Skip point
#
# balance measure
# No. of Reassignments  809
# Skip point
#
# balance measure
# No. of Reassignments  809
# Skip point
#
# balance measure
# No. of Reassignments  809
# 810
# cluster combined count
# [ 4111. 12867.]
# cluster combined percent
# [5671. 7513.]
# cluster combined percent
# [24.2136883 75.7863117]
# [43.01425971 56.98574029]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  810
# Skip point
#
# balance measure
# No. of Reassignments  810
# 811
# cluster combined count
# [ 4112. 12867.]
# cluster combined percent
# [5670. 7513.]
# cluster combined percent
# [24.21815183 75.78184817]
# [43.00993704 56.99006296]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  811
# Skip point
#
# balance measure
# No. of Reassignments  811
# 812
# cluster combined count
# [ 4113. 12867.]
# cluster combined percent
# [5669. 7513.]
# cluster combined percent
# [24.22261484 75.77738516]
# [43.00561372 56.99438628]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  812
# 813
# cluster combined count
# [ 4114. 12867.]
# cluster combined percent
# [5668. 7513.]
# cluster combined percent
# [24.22707732 75.77292268]
# [43.00128974 56.99871026]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  813
# 814
# cluster combined count
# [ 4115. 12867.]
# cluster combined percent
# [5667. 7513.]
# cluster combined percent
# [24.23153928 75.76846072]
# [42.9969651 57.0030349]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  814
# 815
# cluster combined count
# [ 4116. 12867.]
# cluster combined percent
# [5666. 7513.]
# cluster combined percent
# [24.23600071 75.76399929]
# [42.99263981 57.00736019]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  815
# 816
# cluster combined count
# [ 4117. 12867.]
# cluster combined percent
# [5665. 7513.]
# cluster combined percent
# [24.24046161 75.75953839]
# [42.98831386 57.01168614]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# Skip point
#
# balance measure
# No. of Reassignments  816
# 817
# cluster combined count
# [ 4118. 12867.]
# cluster combined percent
# [5664. 7513.]
# cluster combined percent
# [24.24492199 75.75507801]
# [42.98398725 57.01601275]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  817
# Skip point
#
# balance measure
# No. of Reassignments  817
# 818
# cluster combined count
# [ 4119. 12867.]
# cluster combined percent
# [5663. 7513.]
# cluster combined percent
# [24.24938184 75.75061816]
# [42.97965999 57.02034001]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  818
# 819
# cluster combined count
# [ 4120. 12867.]
# cluster combined percent
# [5662. 7513.]
# cluster combined percent
# [24.25384117 75.74615883]
# [42.97533207 57.02466793]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  819
# 820
# cluster combined count
# [ 4121. 12867.]
# cluster combined percent
# [5661. 7513.]
# cluster combined percent
# [24.25829998 75.74170002]
# [42.97100349 57.02899651]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  820
# Skip point
#
# balance measure
# No. of Reassignments  820
# Skip point
#
# balance measure
# No. of Reassignments  820
# Skip point
#
# balance measure
# No. of Reassignments  820
# Skip point
#
# balance measure
# No. of Reassignments  820
# Skip point
#
# balance measure
# No. of Reassignments  820
# Skip point
#
# balance measure
# No. of Reassignments  820
# Skip point
#
# balance measure
# No. of Reassignments  820
# Skip point
#
# balance measure
# No. of Reassignments  820
# 821
# cluster combined count
# [ 4122. 12867.]
# cluster combined percent
# [5660. 7513.]
# cluster combined percent
# [24.26275826 75.73724174]
# [42.96667426 57.03332574]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  821
# 822
# cluster combined count
# [ 4123. 12867.]
# cluster combined percent
# [5659. 7513.]
# cluster combined percent
# [24.26721601 75.73278399]
# [42.96234437 57.03765563]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  822
# Skip point
#
# balance measure
# No. of Reassignments  822
# 823
# cluster combined count
# [ 4124. 12867.]
# cluster combined percent
# [5658. 7513.]
# cluster combined percent
# [24.27167324 75.72832676]
# [42.95801382 57.04198618]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  823
# Skip point
#
# balance measure
# No. of Reassignments  823
# Skip point
#
# balance measure
# No. of Reassignments  823
# 824
# cluster combined count
# [ 4125. 12867.]
# cluster combined percent
# [5657. 7513.]
# cluster combined percent
# [24.27612994 75.72387006]
# [42.95368261 57.04631739]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  824
# 825
# cluster combined count
# [ 4126. 12867.]
# cluster combined percent
# [5656. 7513.]
# cluster combined percent
# [24.28058612 75.71941388]
# [42.94935075 57.05064925]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  825
# 826
# cluster combined count
# [ 4127. 12867.]
# cluster combined percent
# [5655. 7513.]
# cluster combined percent
# [24.28504178 75.71495822]
# [42.94501823 57.05498177]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  826
# 827
# cluster combined count
# [ 4128. 12867.]
# cluster combined percent
# [5654. 7513.]
# cluster combined percent
# [24.28949691 75.71050309]
# [42.94068505 57.05931495]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  827
# 828
# cluster combined count
# [ 4129. 12867.]
# cluster combined percent
# [5653. 7513.]
# cluster combined percent
# [24.29395152 75.70604848]
# [42.93635121 57.06364879]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  828
# 829
# cluster combined count
# [ 4130. 12867.]
# cluster combined percent
# [5652. 7513.]
# cluster combined percent
# [24.2984056 75.7015944]
# [42.93201671 57.06798329]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  829
# Skip point
#
# balance measure
# No. of Reassignments  829
# 830
# cluster combined count
# [ 4131. 12867.]
# cluster combined percent
# [5651. 7513.]
# cluster combined percent
# [24.30285916 75.69714084]
# [42.92768156 57.07231844]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  830
# 831
# cluster combined count
# [ 4132. 12867.]
# cluster combined percent
# [5650. 7513.]
# cluster combined percent
# [24.30731219 75.69268781]
# [42.92334574 57.07665426]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  831
# Skip point
#
# balance measure
# No. of Reassignments  831
# Skip point
#
# balance measure
# No. of Reassignments  831
# Skip point
#
# balance measure
# No. of Reassignments  831
# Skip point
#
# balance measure
# No. of Reassignments  831
# Skip point
#
# balance measure
# No. of Reassignments  831
# Skip point
#
# balance measure
# No. of Reassignments  831
# Skip point
#
# balance measure
# No. of Reassignments  831
# Skip point
#
# balance measure
# No. of Reassignments  831
# Skip point
#
# balance measure
# No. of Reassignments  831
# 832
# cluster combined count
# [ 4133. 12867.]
# cluster combined percent
# [5649. 7513.]
# cluster combined percent
# [24.31176471 75.68823529]
# [42.91900927 57.08099073]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  832
# Skip point
#
# balance measure
# No. of Reassignments  832
# Skip point
#
# balance measure
# No. of Reassignments  832
# 833
# cluster combined count
# [ 4134. 12867.]
# cluster combined percent
# [5648. 7513.]
# cluster combined percent
# [24.31621669 75.68378331]
# [42.91467214 57.08532786]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  833
# Skip point
#
# balance measure
# No. of Reassignments  833
# Skip point
#
# balance measure
# No. of Reassignments  833
# Skip point
#
# balance measure
# No. of Reassignments  833
# 834
# cluster combined count
# [ 4135. 12867.]
# cluster combined percent
# [5647. 7513.]
# cluster combined percent
# [24.32066816 75.67933184]
# [42.91033435 57.08966565]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  834
# 835
# cluster combined count
# [ 4136. 12867.]
# cluster combined percent
# [5646. 7513.]
# cluster combined percent
# [24.3251191 75.6748809]
# [42.9059959 57.0940041]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  835
# 836
# cluster combined count
# [ 4137. 12867.]
# cluster combined percent
# [5645. 7513.]
# cluster combined percent
# [24.32956951 75.67043049]
# [42.90165679 57.09834321]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  836
# 837
# cluster combined count
# [ 4138. 12867.]
# cluster combined percent
# [5644. 7513.]
# cluster combined percent
# [24.33401941 75.66598059]
# [42.89731702 57.10268298]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  837
# Skip point
#
# balance measure
# No. of Reassignments  837
# Skip point
#
# balance measure
# No. of Reassignments  837
# Skip point
#
# balance measure
# No. of Reassignments  837
# Skip point
#
# balance measure
# No. of Reassignments  837
# 838
# cluster combined count
# [ 4139. 12867.]
# cluster combined percent
# [5643. 7513.]
# cluster combined percent
# [24.33846878 75.66153122]
# [42.89297659 57.10702341]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  838
# Skip point
#
# balance measure
# No. of Reassignments  838
# Skip point
#
# balance measure
# No. of Reassignments  838
# Skip point
#
# balance measure
# No. of Reassignments  838
# Skip point
#
# balance measure
# No. of Reassignments  838
# Skip point
#
# balance measure
# No. of Reassignments  838
# Skip point
#
# balance measure
# No. of Reassignments  838
# Skip point
#
# balance measure
# No. of Reassignments  838
# 839
# cluster combined count
# [ 4140. 12867.]
# cluster combined percent
# [5642. 7513.]
# cluster combined percent
# [24.34291762 75.65708238]
# [42.8886355 57.1113645]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  839
# Skip point
#
# balance measure
# No. of Reassignments  839
# Skip point
#
# balance measure
# No. of Reassignments  839
# Skip point
#
# balance measure
# No. of Reassignments  839
# Skip point
#
# balance measure
# No. of Reassignments  839
# Skip point
#
# balance measure
# No. of Reassignments  839
# Skip point
#
# balance measure
# No. of Reassignments  839
# Skip point
#
# balance measure
# No. of Reassignments  839
# 840
# cluster combined count
# [ 4141. 12867.]
# cluster combined percent
# [5641. 7513.]
# cluster combined percent
# [24.34736595 75.65263405]
# [42.88429375 57.11570625]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  840
# Skip point
#
# balance measure
# No. of Reassignments  840
# 841
# cluster combined count
# [ 4142. 12867.]
# cluster combined percent
# [5640. 7513.]
# cluster combined percent
# [24.35181375 75.64818625]
# [42.87995134 57.12004866]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  841
# Skip point
#
# balance measure
# No. of Reassignments  841
# 842
# cluster combined count
# [ 4143. 12867.]
# cluster combined percent
# [5639. 7513.]
# cluster combined percent
# [24.35626102 75.64373898]
# [42.87560827 57.12439173]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  842
# Skip point
#
# balance measure
# No. of Reassignments  842
# Skip point
#
# balance measure
# No. of Reassignments  842
# Skip point
#
# balance measure
# No. of Reassignments  842
# 843
# cluster combined count
# [ 4144. 12867.]
# cluster combined percent
# [5638. 7513.]
# cluster combined percent
# [24.36070778 75.63929222]
# [42.87126454 57.12873546]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  843
# 844
# cluster combined count
# [ 4145. 12867.]
# cluster combined percent
# [5637. 7513.]
# cluster combined percent
# [24.36515401 75.63484599]
# [42.86692015 57.13307985]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  844
# 845
# cluster combined count
# [ 4146. 12867.]
# cluster combined percent
# [5636. 7513.]
# cluster combined percent
# [24.36959972 75.63040028]
# [42.8625751 57.1374249]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  845
# 846
# cluster combined count
# [ 4147. 12867.]
# cluster combined percent
# [5635. 7513.]
# cluster combined percent
# [24.3740449 75.6259551]
# [42.85822939 57.14177061]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# Skip point
#
# balance measure
# No. of Reassignments  846
# 847
# cluster combined count
# [ 4148. 12867.]
# cluster combined percent
# [5634. 7513.]
# cluster combined percent
# [24.37848957 75.62151043]
# [42.85388302 57.14611698]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  847
# Skip point
#
# balance measure
# No. of Reassignments  847
# Skip point
#
# balance measure
# No. of Reassignments  847
# Skip point
#
# balance measure
# No. of Reassignments  847
# Skip point
#
# balance measure
# No. of Reassignments  847
# 848
# cluster combined count
# [ 4149. 12867.]
# cluster combined percent
# [5633. 7513.]
# cluster combined percent
# [24.38293371 75.61706629]
# [42.84953598 57.15046402]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  848
# 849
# cluster combined count
# [ 4150. 12867.]
# cluster combined percent
# [5632. 7513.]
# cluster combined percent
# [24.38737733 75.61262267]
# [42.84518828 57.15481172]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  849
# Skip point
#
# balance measure
# No. of Reassignments  849
# Skip point
#
# balance measure
# No. of Reassignments  849
# Skip point
#
# balance measure
# No. of Reassignments  849
# Skip point
#
# balance measure
# No. of Reassignments  849
# 850
# cluster combined count
# [ 4151. 12867.]
# cluster combined percent
# [5631. 7513.]
# cluster combined percent
# [24.39182043 75.60817957]
# [42.84083993 57.15916007]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  850
# Skip point
#
# balance measure
# No. of Reassignments  850
# Skip point
#
# balance measure
# No. of Reassignments  850
# Skip point
#
# balance measure
# No. of Reassignments  850
# 851
# cluster combined count
# [ 4152. 12867.]
# cluster combined percent
# [5630. 7513.]
# cluster combined percent
# [24.396263 75.603737]
# [42.83649091 57.16350909]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  851
# 852
# cluster combined count
# [ 4153. 12867.]
# cluster combined percent
# [5629. 7513.]
# cluster combined percent
# [24.40070505 75.59929495]
# [42.83214123 57.16785877]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  852
# Skip point
#
# balance measure
# No. of Reassignments  852
# Skip point
#
# balance measure
# No. of Reassignments  852
# 853
# cluster combined count
# [ 4154. 12867.]
# cluster combined percent
# [5628. 7513.]
# cluster combined percent
# [24.40514658 75.59485342]
# [42.82779088 57.17220912]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  853
# Skip point
#
# balance measure
# No. of Reassignments  853
# Skip point
#
# balance measure
# No. of Reassignments  853
# 854
# cluster combined count
# [ 4155. 12867.]
# cluster combined percent
# [5627. 7513.]
# cluster combined percent
# [24.40958759 75.59041241]
# [42.82343988 57.17656012]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  854
# Skip point
#
# balance measure
# No. of Reassignments  854
# Skip point
#
# balance measure
# No. of Reassignments  854
# Skip point
#
# balance measure
# No. of Reassignments  854
# 855
# cluster combined count
# [ 4156. 12867.]
# cluster combined percent
# [5626. 7513.]
# cluster combined percent
# [24.41402808 75.58597192]
# [42.81908821 57.18091179]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  855
# Skip point
#
# balance measure
# No. of Reassignments  855
# Skip point
#
# balance measure
# No. of Reassignments  855
# Skip point
#
# balance measure
# No. of Reassignments  855
# Skip point
#
# balance measure
# No. of Reassignments  855
# Skip point
#
# balance measure
# No. of Reassignments  855
# Skip point
#
# balance measure
# No. of Reassignments  855
# Skip point
#
# balance measure
# No. of Reassignments  855
# Skip point
#
# balance measure
# No. of Reassignments  855
# Skip point
#
# balance measure
# No. of Reassignments  855
# 856
# cluster combined count
# [ 4157. 12867.]
# cluster combined percent
# [5625. 7513.]
# cluster combined percent
# [24.41846805 75.58153195]
# [42.81473588 57.18526412]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  856
# Skip point
#
# balance measure
# No. of Reassignments  856
# 857
# cluster combined count
# [ 4158. 12867.]
# cluster combined percent
# [5624. 7513.]
# cluster combined percent
# [24.42290749 75.57709251]
# [42.81038289 57.18961711]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  857
# Skip point
#
# balance measure
# No. of Reassignments  857
# Skip point
#
# ...
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# Skip point
#
# balance measure
# No. of Reassignments  912
# 913
# cluster combined count
# [ 4214. 12867.]
# cluster combined percent
# [5568. 7513.]
# cluster combined percent
# [24.67068673 75.32931327]
# [42.56555309 57.43444691]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  913
# Skip point
#
# balance measure
# No. of Reassignments  913
# 914
# cluster combined count
# [ 4215. 12867.]
# cluster combined percent
# [5567. 7513.]
# cluster combined percent
# [24.67509659 75.32490341]
# [42.56116208 57.43883792]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  914
# Skip point
#
# balance measure
# No. of Reassignments  914
# 915
# cluster combined count
# [ 4216. 12867.]
# cluster combined percent
# [5566. 7513.]
# cluster combined percent
# [24.67950594 75.32049406]
# [42.5567704 57.4432296]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  915
# Skip point
#
# balance measure
# No. of Reassignments  915
# Skip point
#
# balance measure
# No. of Reassignments  915
# Skip point
#
# balance measure
# No. of Reassignments  915
# Skip point
#
# balance measure
# No. of Reassignments  915
# Skip point
#
# balance measure
# No. of Reassignments  915
# 916
# cluster combined count
# [ 4217. 12867.]
# cluster combined percent
# [5565. 7513.]
# cluster combined percent
# [24.68391477 75.31608523]
# [42.55237804 57.44762196]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  916
# Skip point
#
# balance measure
# No. of Reassignments  916
# Skip point
#
# balance measure
# No. of Reassignments  916
# Skip point
#
# balance measure
# No. of Reassignments  916
# Skip point
#
# balance measure
# No. of Reassignments  916
# 917
# cluster combined count
# [ 4218. 12867.]
# cluster combined percent
# [5564. 7513.]
# cluster combined percent
# [24.68832309 75.31167691]
# [42.54798501 57.45201499]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  917
# Skip point
#
# balance measure
# No. of Reassignments  917
# Skip point
#
# balance measure
# No. of Reassignments  917
# Skip point
#
# balance measure
# No. of Reassignments  917
# Skip point
#
# balance measure
# No. of Reassignments  917
# Skip point
#
# balance measure
# No. of Reassignments  917
# Skip point
#
# balance measure
# No. of Reassignments  917
# Skip point
#
# balance measure
# No. of Reassignments  917
# Skip point
#
# balance measure
# No. of Reassignments  917
# 918
# cluster combined count
# [ 4219. 12867.]
# cluster combined percent
# [5563. 7513.]
# cluster combined percent
# [24.69273089 75.30726911]
# [42.54359131 57.45640869]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  918
# Skip point
#
# balance measure
# No. of Reassignments  918
# Skip point
#
# balance measure
# No. of Reassignments  918
# Skip point
#
# balance measure
# No. of Reassignments  918
# 919
# cluster combined count
# [ 4220. 12867.]
# cluster combined percent
# [5562. 7513.]
# cluster combined percent
# [24.69713818 75.30286182]
# [42.53919694 57.46080306]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  919
# Skip point
#
# balance measure
# No. of Reassignments  919
# 920
# cluster combined count
# [ 4221. 12867.]
# cluster combined percent
# [5561. 7513.]
# cluster combined percent
# [24.70154494 75.29845506]
# [42.5348019 57.4651981]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  920
# Skip point
#
# balance measure
# No. of Reassignments  920
# Skip point
#
# balance measure
# No. of Reassignments  920
# Skip point
#
# balance measure
# No. of Reassignments  920
# 921
# cluster combined count
# [ 4222. 12867.]
# cluster combined percent
# [5560. 7513.]
# cluster combined percent
# [24.7059512 75.2940488]
# [42.53040618 57.46959382]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  921
# Skip point
#
# balance measure
# No. of Reassignments  921
# Skip point
#
# balance measure
# No. of Reassignments  921
# Skip point
#
# balance measure
# No. of Reassignments  921
# Skip point
#
# balance measure
# No. of Reassignments  921
# Skip point
#
# balance measure
# No. of Reassignments  921
# Skip point
#
# balance measure
# No. of Reassignments  921
# 922
# cluster combined count
# [ 4223. 12867.]
# cluster combined percent
# [5559. 7513.]
# cluster combined percent
# [24.71035693 75.28964307]
# [42.52600979 57.47399021]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  922
# Skip point
#
# balance measure
# No. of Reassignments  922
# Skip point
#
# balance measure
# No. of Reassignments  922
# Skip point
#
# balance measure
# No. of Reassignments  922
# Skip point
#
# balance measure
# No. of Reassignments  922
# Skip point
#
# balance measure
# No. of Reassignments  922
# 923
# cluster combined count
# [ 4224. 12867.]
# cluster combined percent
# [5558. 7513.]
# cluster combined percent
# [24.71476216 75.28523784]
# [42.52161273 57.47838727]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  923
# Skip point
#
# balance measure
# No. of Reassignments  923
# Skip point
#
# balance measure
# No. of Reassignments  923
# Skip point
#
# balance measure
# No. of Reassignments  923
# 924
# cluster combined count
# [ 4225. 12867.]
# cluster combined percent
# [5557. 7513.]
# cluster combined percent
# [24.71916686 75.28083314]
# [42.517215 57.482785]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  924
# 925
# cluster combined count
# [ 4226. 12867.]
# cluster combined percent
# [5556. 7513.]
# cluster combined percent
# [24.72357105 75.27642895]
# [42.51281659 57.48718341]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  925
# 926
# cluster combined count
# [ 4227. 12867.]
# cluster combined percent
# [5555. 7513.]
# cluster combined percent
# [24.72797473 75.27202527]
# [42.50841751 57.49158249]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  926
# Skip point
#
# balance measure
# No. of Reassignments  926
# Skip point
#
# balance measure
# No. of Reassignments  926
# Skip point
#
# balance measure
# No. of Reassignments  926
# Skip point
#
# balance measure
# No. of Reassignments  926
# Skip point
#
# balance measure
# No. of Reassignments  926
# 927
# cluster combined count
# [ 4228. 12867.]
# cluster combined percent
# [5554. 7513.]
# cluster combined percent
# [24.73237789 75.26762211]
# [42.50401775 57.49598225]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  927
# Skip point
#
# balance measure
# No. of Reassignments  927
# Skip point
#
# balance measure
# No. of Reassignments  927
# Skip point
#
# balance measure
# No. of Reassignments  927
# Skip point
#
# balance measure
# No. of Reassignments  927
# 928
# cluster combined count
# [ 4229. 12867.]
# cluster combined percent
# [5553. 7513.]
# cluster combined percent
# [24.73678053 75.26321947]
# [42.49961733 57.50038267]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  928
# Skip point
#
# balance measure
# No. of Reassignments  928
# Skip point
#
# balance measure
# No. of Reassignments  928
# Skip point
#
# balance measure
# No. of Reassignments  928
# Skip point
#
# balance measure
# No. of Reassignments  928
# Skip point
#
# balance measure
# No. of Reassignments  928
# Skip point
#
# balance measure
# No. of Reassignments  928
# 929
# cluster combined count
# [ 4230. 12867.]
# cluster combined percent
# [5552. 7513.]
# cluster combined percent
# [24.74118266 75.25881734]
# [42.49521623 57.50478377]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  929
# Skip point
#
# balance measure
# No. of Reassignments  929
# Skip point
#
# balance measure
# No. of Reassignments  929
# Skip point
#
# balance measure
# No. of Reassignments  929
# Skip point
#
# balance measure
# No. of Reassignments  929
# 930
# cluster combined count
# [ 4231. 12867.]
# cluster combined percent
# [5551. 7513.]
# cluster combined percent
# [24.74558428 75.25441572]
# [42.49081445 57.50918555]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  930
# 931
# cluster combined count
# [ 4232. 12867.]
# cluster combined percent
# [5550. 7513.]
# cluster combined percent
# [24.74998538 75.25001462]
# [42.486412 57.513588]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  931
# 932
# cluster combined count
# [ 4233. 12867.]
# cluster combined percent
# [5549. 7513.]
# cluster combined percent
# [24.75438596 75.24561404]
# [42.48200888 57.51799112]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  932
# Skip point
#
# balance measure
# No. of Reassignments  932
# 933
# cluster combined count
# [ 4234. 12867.]
# cluster combined percent
# [5548. 7513.]
# cluster combined percent
# [24.75878604 75.24121396]
# [42.47760508 57.52239492]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# Skip point
#
# balance measure
# No. of Reassignments  933
# 934
# cluster combined count
# [ 4235. 12867.]
# cluster combined percent
# [5547. 7513.]
# cluster combined percent
# [24.76318559 75.23681441]
# [42.47320061 57.52679939]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  934
# 935
# cluster combined count
# [ 4236. 12867.]
# cluster combined percent
# [5546. 7513.]
# cluster combined percent
# [24.76758463 75.23241537]
# [42.46879547 57.53120453]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  935
# Skip point
#
# balance measure
# No. of Reassignments  935
# Skip point
#
# balance measure
# No. of Reassignments  935
# Skip point
#
# balance measure
# No. of Reassignments  935
# 936
# cluster combined count
# [ 4237. 12867.]
# cluster combined percent
# [5545. 7513.]
# cluster combined percent
# [24.77198316 75.22801684]
# [42.46438965 57.53561035]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  936
# Skip point
#
# balance measure
# No. of Reassignments  936
# 937
# cluster combined count
# [ 4238. 12867.]
# cluster combined percent
# [5544. 7513.]
# cluster combined percent
# [24.77638118 75.22361882]
# [42.45998315 57.54001685]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  937
# Skip point
#
# balance measure
# No. of Reassignments  937
# Skip point
#
# balance measure
# No. of Reassignments  937
# Skip point
#
# balance measure
# No. of Reassignments  937
# Skip point
#
# balance measure
# No. of Reassignments  937
# Skip point
#
# balance measure
# No. of Reassignments  937
# Skip point
#
# balance measure
# No. of Reassignments  937
# Skip point
#
# balance measure
# No. of Reassignments  937
# Skip point
#
# balance measure
# No. of Reassignments  937
# Skip point
#
# balance measure
# No. of Reassignments  937
# 938
# cluster combined count
# [ 4239. 12867.]
# cluster combined percent
# [5543. 7513.]
# cluster combined percent
# [24.78077867 75.21922133]
# [42.45557598 57.54442402]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  938
# Skip point
#
# balance measure
# No. of Reassignments  938
# Skip point
#
# balance measure
# No. of Reassignments  938
# Skip point
#
# balance measure
# No. of Reassignments  938
# Skip point
#
# balance measure
# No. of Reassignments  938
# 939
# cluster combined count
# [ 4240. 12867.]
# cluster combined percent
# [5542. 7513.]
# cluster combined percent
# [24.78517566 75.21482434]
# [42.45116813 57.54883187]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  939
# Skip point
#
# balance measure
# No. of Reassignments  939
# Skip point
#
# balance measure
# No. of Reassignments  939
# Skip point
#
# balance measure
# No. of Reassignments  939
# Skip point
#
# balance measure
# No. of Reassignments  939
# 940
# cluster combined count
# [ 4241. 12867.]
# cluster combined percent
# [5541. 7513.]
# cluster combined percent
# [24.78957213 75.21042787]
# [42.44675961 57.55324039]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  940
# 941
# cluster combined count
# [ 4242. 12867.]
# cluster combined percent
# [5540. 7513.]
# cluster combined percent
# [24.79396809 75.20603191]
# [42.44235042 57.55764958]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  941
# Skip point
#
# balance measure
# No. of Reassignments  941
# Skip point
#
# balance measure
# No. of Reassignments  941
# 942
# cluster combined count
# [ 4243. 12867.]
# cluster combined percent
# [5539. 7513.]
# cluster combined percent
# [24.79836353 75.20163647]
# [42.43794055 57.56205945]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  942
# 943
# cluster combined count
# [ 4244. 12867.]
# cluster combined percent
# [5538. 7513.]
# cluster combined percent
# [24.80275846 75.19724154]
# [42.43353 57.56647]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# No. of Reassignments  943
# 944
# cluster combined count
# [ 4245. 12867.]
# cluster combined percent
# [5537. 7513.]
# cluster combined percent
# [24.80715288 75.19284712]
# [42.42911877 57.57088123]
# combined count [ 9782. 20380.]
# combined percent [32.43153637 67.56846363]
#
#
# balance measure
# Clusters balanced
# cluster_quality is  0.10846199400637381
# fairness_quality is  0.17302360634972846
# Objective function==========================================  0.9354383876566453
# Initial Cluster  0 size  17008
# Last Cluster  0 size  17112
# Initial Cluster  1 size  13154
# Last Cluster  1 size  13050
# Initial Clustering Quality  0.11090011130345234
# Last Clustering Quality  0.10846199400637381
# Initial Fairness Quality  0.2380420006438631
# Last Fairness Quality  0.17302360634972846
# No change?  0
# Failed?  0
#
# Last clustering to predict income:
# cluster  0 percentage <=50k  59.560542309490415
# cluster  0 percentage >50k  40.439457690509585
# cluster  1 percentage <=50k  95.49425287356323
# cluster  1 percentage >50k  4.505747126436781
# Clustering quality change =  -2.198480477992661
